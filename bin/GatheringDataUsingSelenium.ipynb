# %%
# Packages
# pip3 install PyExecJS
# pip3 install selenium


## Importing Package
## Official Page: https://github.com/SeleniumHQ/selenium/tree/master/py
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
import execjs
import time, sys, glob

from Sel1_LoadDriver import driver
from Sel2_InitiateSearch import search

'''
from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 800))  
display.start()
'''

    
# option: 'Chrome', 'Mozilla', 'EDGE', ''
driver = driver('Chrome').getDriver()

d = dict(driver.capabilities)
print('Driver Configuration')
for ele in d.keys():
    print(ele, ':', d[ele])
time.sleep(2)
# Out:
# Loading Chrome
# Trying to locate the required driver at "../data/driver/chromedriver/linux/"
# ['../data/driver/chromedriver/linux/chromedriver']
# Driver file has been located and loaded
# Driver Configuration
# acceptInsecureCerts : False
# acceptSslCerts : False
# applicationCacheEnabled : False
# browserConnectionEnabled : False
# browserName : chrome
# chrome : {'chromedriverVersion': '73.0.3683.20 (8e2b610813e167eee3619ac4ce6e42e3ec622017)', 'userDataDir': '/tmp/.com.google.Chrome.19Ui6G'}
# cssSelectorsEnabled : True
# databaseEnabled : False
# goog:chromeOptions : {'debuggerAddress': 'localhost:37891'}
# handlesAlerts : True
# hasTouchScreen : False
# javascriptEnabled : True
# locationContextEnabled : True
# mobileEmulationEnabled : False
# nativeEvents : True
# networkConnectionEnabled : False
# pageLoadStrategy : normal
# platform : Linux
# proxy : {}
# rotatable : False
# setWindowRect : True
# strictFileInteractability : False
# takesHeapSnapshot : True
# takesScreenshot : True
# timeouts : {'implicit': 0, 'pageLoad': 300000, 'script': 30000}
# unexpectedAlertBehaviour : ignore
# version : 70.0.3538.77
# webStorageEnabled : True

# %%
## 'GoogleSearch', 'GoogleNewsSearch', 'GoogleScholarSearch', 'GoogleImageSearch'
A = search(driver, 'GoogleScholarSearch') 
A.searchAndOpenNewTab('JP Morgan AI')
# Out:
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 412, 'y': 322}
# Window is positioned at: {'height': 1080, 'width': 1920, 'x': 0, 'y': 0}
# Current Tab ID: CDwindow-2707F54273F8C6539418E487F79E1AE2
# Current URL: https://www.google.com/
# Searching for "JP Morgan AI"
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 539, 'y': 1753}
# Window is positioned at: {'height': 1080, 'width': 1920, 'x': 0, 'y': 0}
# Current Tab ID: CDwindow-2707F54273F8C6539418E487F79E1AE2
# Current URL: https://www.google.com/search?source=hp&ei=bylhXPu3Nc6m9QPOh5XoAQ&q=JP+Morgan+AI&btnK=Google+Search&oq=JP+Morgan+AI&gs_l=psy-ab.3..0l10.2191.3203..3494...0.0..0.167.1259.6j6......0....1..gws-wiz.....0..0i131j0i10.lVjYbRqYNyY
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 393, 'y': 235}
# Window is positioned at: {'height': 1080, 'width': 1920, 'x': 0, 'y': 0}
# Current Tab ID: CDwindow-2707F54273F8C6539418E487F79E1AE2
# Current URL: https://scholar.google.co.in/
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 670, 'y': 235}
# Window is positioned at: {'height': 1080, 'width': 1920, 'x': 0, 'y': 0}
# Current Tab ID: CDwindow-3BF34AD3BCCA2A541C1A65DA81C6A1B3
# Current URL: https://scholar.google.co.in/
# Searching for "JP Morgan AI"
# {'NewTab': 'CDwindow-3BF34AD3BCCA2A541C1A65DA81C6A1B3',
#  'OldTab': 'CDwindow-2707F54273F8C6539418E487F79E1AE2'}

# %%
# driver.page_source

# %%
Heading = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[1]/div/article/div[1]')
source = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]/div/article/div[2]/div/div')
date = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]/div/article/div[2]/div/time')
# summary = driver.find_element_by_xpath('')

Heading.text, source.text, date.text

# %%
Heading = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[1]/div/article/div[1]')
New = Heading.text
print(New)

source = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]/div/article/div[2]/div/div')
New = source.text
print(New)
# Out:
# J.P. Morgan's AI team continues big hiring push
# J.P. Morgan is pulling out all the stops to add talented AI engineers.
# Business Insider

# %%
/html/body/div[6]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]

//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[1]/div/article/a
//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]/div/article/a
//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[3]/div/article/a
//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[4]/div/article/a

# %%
Headline_element = driver.find_element_by_xpath('//*[@id="yDmH0d"]')

News = Headline_element.text.split('...\n')
import pandas as pd


News = [ ele.split('\n') for ele in News ]
print(News[0:5])
listLens = [ len(ele) for ele in News ]
print(listLens[0:5])

def mode(arr) :
    m = max([arr.count(a) for a in arr])
    return [x for x in arr if arr.count(x) == m][0] if m>1 else None
# Out:
# [['News', 'arrow_drop_down', 'Sign in', 'play_newsstand', 'Top stories', 'person', 'For you', 'star_border', 'Favourites', 'search', 'Saved searches', 'flag', 'India', 'public', 'World', 'room', 'Local', 'business', 'Business', 'memory', 'Technology', 'theaters', 'Entertainment', 'directions_bike', 'Sports', 'experiment', 'Science', 'fitness_center', 'Health', 'Language & region', 'English | India', 'Settings', 'Get the Android app', 'open_in_new', 'Get the iOS app', 'open_in_new', 'Send feedback', 'Help', 'open_in_new', 'Privacy · Terms · About Google', "J.P. Morgan's AI team continues big hiring push", 'J.P. Morgan is pulling out all the stops to add talented AI engineers.', 'eFinancialCareers', '19 days ago', "Wall Street's running into the stark reality of AI", "JPMorgan's copresident Daniel Pinto spoke with Business Insider recently about the complexity of making usable the massive amounts of data that the bank "], ['Business Insider', '5 days ago', "A fintech executive at JPMorgan explains why AI isn't all it's cracked up to be when it comes to helping people manage money", 'JPMorgan announced the five fintech firms joining its Financial Solutions Lab, which is aimed at helping customers who are living paycheck to paycheck.', 'Business Insider', '26 days ago', 'JPMorgan Healthcare Conference roundup', 'This story was delivered to Business Insider Intelligence "Digital Health Briefing" subscribers hours before appearing on Business Insider. To be the first to know, '], ['Business Insider', '27 days ago', 'How to Set Up an AI Center of Excellence', 'Artificial intelligence is one of the most powerful technologies for reshaping business in decades. It has the ability to optimize many processes throughout '], ['HBR.org Daily', '25 days ago', 'Tesla To Sell Merchandise On Amazon, Facebook Acquires AI Startup Grokstyle: News From Tech And Startup World', "Last week, Amazon CEO Jeff Bezos made it to the headlines after he accused 'The National Enquirer' of extortion and blackmail.", 'Inc42 Media', 'y

# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27  Coupa has enhanced its business spend manageme...
# 28                                               None
# 29  J.P. Morgan may have lost one artificial intel...
# ..                                                ...
# 38                                               None
# 39  Professor Manuela Veloso of Carnegie Mellon wi...
# 40                                               None
# 41  The heads of major systematic investment firms...
# 42  Artificial intelligence is in our phones, begi...
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50  Banking Roundup: Wells Fargo cuts 638 mortgage...
# 51  WASHINGTON--(BUSINESS WIRE)--The founding memb...
# 52                                               None
# 53                                       2 months ago
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58  Google's co-founder Sergey Brin has written ab...
# 59                                               None
# 60  JPMorgan has hired a machine-learning expert f...
# 61                                               None
# 62                                               None
# 63  SAN FRANCISCO—We certainly like to offer a ful...
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                     Search results
#
#                                                    8   \
# 0                                          Favourites
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   JPMorgan Chase & Co. increased its stake in Ar...
# 6                                                None
# 7   JPMorgan just made another high-profile artifi...
# 8   JPMorgan Chase is doubling down on artificial ...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                         PYMNTS.com
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# ..                                                ...
# 38                                               None
# 39                                       Fox Business
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50  The nation's largest banks — such as JPMorgan ...
# 51                                               None
# 52                                               None
# 53  JPMorgan wants its financial analysts to be ab...
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                     Financial News
# 61                                               None
# 62                                               None
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                        star_border
#
#                                                    9   \
# 0                                              search
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   JPMorgan Chase just made another hire that pro...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                       7 months ago
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# ..                                                ...
# 38                                               None
# 39                                       9 months ago
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53  JPMorgan Chase is putting all its analysts and...
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60  How Artificial Intelligence Is Helping Financi...
# 61                                               None
# 62                                               None
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               Save
#
#                           ...                                     36    37  \
# 0                         ...                          Send feedback  Help
# 1                         ...                                   None  None
# 2                         ...                                   None  None
# 3                         ...                                   None  None
# 4                         ...                                   None  None
# 5                         ...                                   None  None
# 6                         ...                                   None  None
# 7                         ...                                   None  None
# 8                         ...                                   None  None
# 9                         ...                                   None  None
# 10                        ...                                   None  None
# 11                        ...                                   None  None
# 12                        ...                                   None  None
# 13                        ...                                   None  None
# 14                        ...                                   None  None
# 15                        ...                                   None  None
# 16                        ...                                   None  None
# 17                        ...                                   None  None
# 18                        ...                                   None  None
# 19                        ...                                   None  None
# 20                        ...                                   None  None
# 21                        ...                                   None  None
# 22                        ...                                   None  None
# 23                        ...                                   None  None
# 24                        ...                                   None  None
# 25                        ...                                   None  None
# 26                        ...                                   None  None
# 27                        ...                                   None  None
# 28                        ...                                   None  None
# 29                        ...                                   None  None
# ..                        ...                                    ...   ...
# 38                        ...                                   None  None
# 39                        ...                                   None  None
# 40                        ...                                   None  None
# 41                        ...                                   None  None
# 42                        ...                                   None  None
# 43                        ...                                   None  None
# 44                        ...                                   None  None
# 45                        ...                                   None  None
# 46                        ...                                   None  None
# 47                        ...                                   None  None
# 48                        ...                                   None  None
# 49                        ...                                   None  None
# 50                        ...                                   None  None
# 51                        ...                                   None  None
# 52                        ...                                   None  None
# 53                        ...                                   None  None
# 54                        ...                                   None  None
# 55                        ...                                   None  None
# 56                        ...                                   None  None
# 57                        ...                                   None  None
# 58                        ...                                   None  None
# 59                        ...                                   None  None
# 60                        ...                                   None  None
# 61                        ...                                   None  None
# 62                        ...                                   None  None
# 63                        ...                                   None  None
# 64                        ...                                   None  None
# 65                        ...                                   None  None
# 66                        ...                                   None  None
# 67                        ...                                   None  None
#
#              38                              39  \
# 0   open_in_new  Privacy · Terms · About Google
# 1          None                            None
# 2          None                            None
# 3          None                            None
# 4          None                            None
# 5          None                            None
# 6          None                            None
# 7          None                            None
# 8          None                            None
# 9          None                            None
# 10         None                            None
# 11         None                            None
# 12         None                            None
# 13         None                            None
# 14         None                            None
# 15         None                            None
# 16         None                            None
# 17         None                            None
# 18         None                            None
# 19         None                            None
# 20         None                            None
# 21         None                            None
# 22         None                            None
# 23         None                            None
# 24         None                            None
# 25         None                            None
# 26         None                            None
# 27         None                            None
# 28         None                            None
# 29         None                            None
# ..          ...                             ...
# 38         None                            None
# 39         None                            None
# 40         None                            None
# 41         None                            None
# 42         None                            None
# 43         None                            None
# 44         None                            None
# 45         None                            None
# 46         None                            None
# 47         None                            None
# 48         None                            None
# 49         None                            None
# 50         None                            None
# 51         None                            None
# 52         None                            None
# 53         None                            None
# 54         None                            None
# 55         None                            None
# 56         None                            None
# 57         None                            None
# 58         None                            None
# 59         None                            None
# 60         None                            None
# 61         None                            None
# 62         None                            None
# 63         None                            None
# 64         None                            None
# 65         None                            None
# 66         None                            None
# 67         None                            None
#
#                                                  40  \
# 0   J.P. Morgan's AI team continues big hiring push
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                              None
# 5                                              None
# 6                                              None
# 7                                              None
# 8                                              None
# 9                                              None
# 10                                             None
# 11                                             None
# 12                                             None
# 13                                             None
# 14                                             None
# 15                                             None
# 16                                             None
# 17                                             None
# 18                                             None
# 19                                             None
# 20                                             None
# 21                                             None
# 22                                             None
# 23                                             None
# 24                                             None
# 25                                             None
# 26                                             None
# 27                                             None
# 28                                             None
# 29                                             None
# ..                                              ...
# 38                                             None
# 39                                             None
# 40                                             None
# 41                                             None
# 42                                             None
# 43                                             None
# 44                                             None
# 45                                             None
# 46                                             None
# 47                                             None
# 48                                             None
# 49                                             None
# 50                                             None
# 51                                             None
# 52                                             None
# 53                                             None
# 54                                             None
# 55                                             None
# 56                                             None
# 57                                             None
# 58                                             None
# 59                                             None
# 60                                             None
# 61                                             None
# 62                                             None
# 63                                             None
# 64                                             None
# 65                                             None
# 66                                             None
# 67                                             None
#
#                                                    41                 42  \
# 0   J.P. Morgan is pulling out all the stops to ad...  eFinancialCareers
# 1                                                None               None
# 2                                                None               None
# 3                                                None               None
# 4                                                None               None
# 5                                                None               None
# 6                                                None               None
# 7                                                None               None
# 8                                                None               None
# 9                                                None               None
# 10                                               None               None
# 11                                               None               None
# 12                                               None               None
# 13                                               None               None
# 14                                               None               None
# 15                                               None               None
# 16                                               None               None
# 17                                               None               None
# 18                                               None               None
# 19                                               None               None
# 20                                               None               None
# 21                                               None               None
# 22                                               None               None
# 23                                               None               None
# 24                                               None               None
# 25                                               None               None
# 26                                               None               None
# 27                                               None               None
# 28                                               None               None
# 29                                               None               None
# ..                                                ...                ...
# 38                                               None               None
# 39                                               None               None
# 40                                               None               None
# 41                                               None               None
# 42                                               None               None
# 43                                               None               None
# 44                                               None               None
# 45                                               None               None
# 46                                               None               None
# 47                                               None               None
# 48                                               None               None
# 49                                               None               None
# 50                                               None               None
# 51                                               None               None
# 52                                               None               None
# 53                                               None               None
# 54                                               None               None
# 55                                               None               None
# 56                                               None               None
# 57                                               None               None
# 58                                               None               None
# 59                                               None               None
# 60                                               None               None
# 61                                               None               None
# 62                                               None               None
# 63                                               None               None
# 64                                               None               None
# 65                                               None               None
# 66                                               None               None
# 67                                               None               None
#
#              43                                                 44  \
# 0   19 days ago  Wall Street's running into the stark reality o...
# 1          None                                               None
# 2          None                                               None
# 3          None                                               None
# 4          None                                               None
# 5          None                                               None
# 6          None                                               None
# 7          None                                               None
# 8          None                                               None
# 9          None                                               None
# 10         None                                               None
# 11         None                                               None
# 12         None                                               None
# 13         None                                               None
# 14         None                                               None
# 15         None                                               None
# 16         None                                               None
# 17         None                                               None
# 18         None                                               None
# 19         None                                               None
# 20         None                                               None
# 21         None                                               None
# 22         None                                               None
# 23         None                                               None
# 24         None                                               None
# 25         None                                               None
# 26         None                                               None
# 27         None                                               None
# 28         None                                               None
# 29         None                                               None
# ..          ...                                                ...
# 38         None                                               None
# 39         None                                               None
# 40         None                                               None
# 41         None                                               None
# 42         None                                               None
# 43         None                                               None
# 44         None                                               None
# 45         None                                               None
# 46         None                                               None
# 47         None                                               None
# 48         None                                               None
# 49         None                                               None
# 50         None                                               None
# 51         None                                               None
# 52         None                                               None
# 53         None                                               None
# 54         None                                               None
# 55         None                                               None
# 56         None                                               None
# 57         None                                               None
# 58         None                                               None
# 59         None                                               None
# 60         None                                               None
# 61         None                                               None
# 62         None                                               None
# 63         None                                               None
# 64         None                                               None
# 65         None                                               None
# 66         None                                               None
# 67         None                                               None
#
#                                                    45
# 0   JPMorgan's copresident Daniel Pinto spoke with...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# ..                                                ...
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45                                               None
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
# 62                                               None
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
#
# [68 rows x 46 columns]

# %%
def listbreak(li, breakIntoLenOf):
    liLeft = li
    brokenLi = []
    while len(liLeft) > 0:
#         print(":",liLeft[0:breakIntoLenOf])
        brokenLi.append(liLeft[0:breakIntoLenOf])
        liLeft = liLeft[breakIntoLenOf:]
    return brokenLi#( ele for ele in brokenLi )

li = ['Pakistan Today', '5 days ago', "Supreme Court rules that Karachi's JPMC will remain a federal institution", "It has rejected the Sindh govt's plea for control of the hospital.", 'Samaa Digital', '25 days ago', 'UTP who fled from JPMC may have killed traffic cop: police', 'Police believe that the under-trial prisoner (UTP) who had escaped from the Jinnah Postgraduate Medical Centre (JPMC) on January 12 may be responsible for ']
A = (ele for ele in listbreak(li,4))
type(A)
# Out:
# generator

# %%
MoreProcessedNews1, indToRemove1, MoreProcessedNews2, indToRemove2 = [], [], [], []

NewsIssue1 = [ (i,News[i]) for i in range(len(listLens)) if (listLens[i] > mode(listLens)) and (listLens[i]%mode(listLens)==0) ]
indToRemove1 = [ ele[0] for ele in NewsIssue1 ]
for ele in NewsIssue1:
    for li in listbreak(ele[1], mode(listLens)):
        MoreProcessedNews1 += tempLi

NewsIssue2 = [ (i,News[i]) for i in range(len(listLens)) if (listLens[i] > mode(listLens)) and (listLens[i]%mode(listLens)!=0) ]
indToRemove2 = [ ele[0] for ele in NewsIssue2 ]
for ele in NewsIssue2:
    for li in listbreak(ele[1], mode(listLens)):
        MoreProcessedNews2 += tempLi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a58311fe6308> in <module>()
#       5 for ele in NewsIssue1:
#       6     for li in listbreak(ele[1], mode(listLens)):
# ----> 7         MoreProcessedNews1 += tempLi
#       8
#       9 NewsIssue2 = [ (i,News[i]) for i in range(len(listLens)) if (listLens[i] > mode(listLens)) and (listLens[i]%mode(listLens)!=0) ]
#
# NameError: name 'tempLi' is not defined

# %%
pd.DataFrame(CorrectNews)

# %%
CorrectNews = [ ele for ele in News if len(ele) <= mode(listLens) ]
modeLenInColDict = {}
for i in range(mode(listLens)):
    print(i)
    colLi = [ ele[i] for ele in CorrectNews ]
    colLenLi = [ len(ele) for ele in colLi ]
    modeLenInColDict['col'+str(i)] = mode(colLi)
modeLenInColDict

# %%
for ele in NewsIssue2:
    print(ele[1])
    print()

# %%
try:
    for i in range(0,1):
        driver.get("https://www.google.com/")
        driver.quit
except Exception as excpt:
    print(excpt)
    if 'about:neterror' in excpt:
        msg = 'Network Issue: Internet not available.'
        print(msg); raise Exception(msg)

# %%
# go to the google home page
driver.get("https://www.moneycontrol.com/news/commodities-news-94.html")
driver.find_element_by_id('search_str').send_keys('airtel')
driver.find_element_by_id("search_str").send_keys(Keys.ENTER)
a = driver.find_element_by_xpath("//a[contains(text(),'NEWS')]")
a.click() 
content = driver.find_elements_by_tag_name("strong")
# text = list()
# for i in range(0,40):
    
#     print content.text
#     if len(content.text) > 10:
#         text.append(content.text)
# element=driver.find_element_by_id("slider")
# dt = driver.find_element_by_tag_name("dt")
# print dt
# cl = element.find_element_by_partial_link_text("news")
# cl.click()
# time.sleep(10)
# news = driver.find_element_by_xpath("/html[1]/body[1]/div[3]/div[3]/div[1]/div[3]/div[2]/div[11]/div[1]/div[2]/div[1]/dl[1]/dt[3]/a[1]")
# href = news.get_attribute('href')
# print hreffrom selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
import execjs
import time
'''
from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 800))  
display.start()
'''
options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
#binary='/usr/bin/firefox'
options.add_argument('--ignore-certificate-errors')
options.add_argument("--test-type")
# Create a new instance of the Firefox driver
#driver = webdriver.Firefox(binary)

binary = '/usr/bin/chromedriver'
driver =  webdriver.Chrome(binary,chrome_options = options)

# go to the google home page
driver.get("https://www.moneycontrol.com/news/commodities-news-94.html")
driver.find_element_by_id('search_str').send_keys('airtel')
driver.find_element_by_id("search_str").send_keys(Keys.ENTER)
a = driver.find_element_by_xpath("//a[contains(text(),'NEWS')]")
a.click() 
content = driver.find_elements_by_tag_name("strong")
# text = list()
# for i in range(0,40):
    
#     print content.text
#     if len(content.text) > 10:
#         text.append(content.text)
# element=driver.find_element_by_id("slider")
# dt = driver.find_element_by_tag_name("dt")
# print dt
# cl = element.find_element_by_partial_link_text("news")
# cl.click()
# time.sleep(10)
# news = driver.find_element_by_xpath("/html[1]/body[1]/div[3]/div[3]/div[1]/div[3]/div[2]/div[11]/div[1]/div[2]/div[1]/dl[1]/dt[3]/a[1]")
# href = news.get_attribute('href')
# print href

# %%
## Other Resource

## Selenium Other Command
# driver.back()
# driver.fullscreen_window()
# driver.minimize_window()
# driver.maximize_window()
# driver.refresh()
# driver.save_screenshot(filename='TempScreenshot.png')

## Get All Active Windows/Tabs
activeHandles = driver.window_handles

## Switch Tabs
driver.switch_to.window(activeHandles[0])
driver.switch_to.window(activeHandles[1])

## Opens another Window
# driver.execute_script("window.open('https://www.yahoo.com')")

## Open New Tab
# driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL +"t")#+Keys.TAB) #Doesn't work
homeButton = driver.find_element_by_xpath('/html/body/div/div[3]/div[1]/div/div/div/div[2]/div[2]/div[1]/a')
NewTab = Keys.CONTROL + Keys.ENTER#+ 'T'
homeButton.send_keys(NewTab)
