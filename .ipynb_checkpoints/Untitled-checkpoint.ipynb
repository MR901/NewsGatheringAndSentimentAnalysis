# %%
# Packages
# pip3 install PyExecJS
# pip3 install selenium


## Importing Package
## Official Page: https://github.com/SeleniumHQ/selenium/tree/master/py
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
import execjs
import time, sys, glob

from Sel1_LoadDriver import driver
from Sel2_InitiateSearch import search

'''
from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 800))  
display.start()
'''

    
# option: 'Chrome', 'Mozilla', 'EDGE', ''
driver = driver('Chrome').getDriver()

d = dict(driver.capabilities)
print('Driver Configuration')
for ele in d.keys():
    print(ele, ':', d[ele])
time.sleep(2)



## 'GoogleSearch', 'GoogleNewsSearch', 'GoogleScholarSearch', 'GoogleImageSearch'
A = search(driver, 'GoogleNewsSearch') 
A.searchAndOpenNewTab('JPMC')
# Out:
# Loading Chrome
# Trying to locate the required driver at "driver/chromedriver/linux/"
# Driver file has been located and loaded
# Driver Configuration
# acceptInsecureCerts : False
# acceptSslCerts : False
# applicationCacheEnabled : False
# browserConnectionEnabled : False
# browserName : chrome
# chrome : {'chromedriverVersion': '73.0.3683.20 (8e2b610813e167eee3619ac4ce6e42e3ec622017)', 'userDataDir': '/tmp/.com.google.Chrome.aHgKoW'}
# cssSelectorsEnabled : True
# databaseEnabled : False
# goog:chromeOptions : {'debuggerAddress': 'localhost:41891'}
# handlesAlerts : True
# hasTouchScreen : False
# javascriptEnabled : True
# locationContextEnabled : True
# mobileEmulationEnabled : False
# nativeEvents : True
# networkConnectionEnabled : False
# pageLoadStrategy : normal
# platform : Linux
# proxy : {}
# rotatable : False
# setWindowRect : True
# strictFileInteractability : False
# takesHeapSnapshot : True
# takesScreenshot : True
# timeouts : {'implicit': 0, 'pageLoad': 300000, 'script': 30000}
# unexpectedAlertBehaviour : ignore
# version : 70.0.3538.77
# webStorageEnabled : True
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 270, 'y': 322}
# Window is positioned at: {'height': 994, 'width': 945, 'x': 10, 'y': 37}
# Current Tab ID: CDwindow-669ADDFF7AED91E8413B1CBD9A3C2C9C
# Current URL: https://www.google.com/
# Searching for "JPMC"
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 540, 'y': 2340}
# Window is positioned at: {'height': 994, 'width': 945, 'x': 10, 'y': 37}
# Current Tab ID: CDwindow-669ADDFF7AED91E8413B1CBD9A3C2C9C
# Current URL: https://www.google.com/search?source=hp&ei=NvBgXL6RGcuo9QPVk5rwDw&q=JPMC&btnK=Google+Search&oq=JPMC&gs_l=psy-ab.3...455.476..503...0.0..0.0.0.......0....1..gws-wiz.....0.
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 302, 'y': 9}
# Window is positioned at: {'height': 994, 'width': 945, 'x': 10, 'y': 37}
# Current Tab ID: CDwindow-669ADDFF7AED91E8413B1CBD9A3C2C9C
# Current URL: https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en
#
#  *****  *****  *****  *****  *****  *****  *****
#
# Element visiblity: True
# Element is at:  {'x': 302, 'y': 9}
# Window is positioned at: {'height': 994, 'width': 945, 'x': 10, 'y': 37}
# Current Tab ID: CDwindow-C4911F07AD5E7DE75CFBCDB989334A6E
# Current URL: https://news.google.com/?hl=en-IN&gl=IN&ceid=IN:en
# Searching for "JPMC"
# {'NewTab': 'CDwindow-C4911F07AD5E7DE75CFBCDB989334A6E',
#  'OldTab': 'CDwindow-669ADDFF7AED91E8413B1CBD9A3C2C9C'}

# %%
# driver.page_source

# %%
Heading = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[1]/div/article/div[1]')
source = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]/div/article/div[2]/div/div')
date = driver.find_element_by_xpath('//*[@id="yDmH0d"]/c-wiz[2]/div/div[1]/div/main/c-wiz/div[1]/div[2]/div/article/div[2]/div/time')
# summary = driver.find_element_by_xpath('')

Heading.text, source.text, date.text
# Out:
# ("Years first Congo virus case reported at JPMC\nThe city's first case in 2019 of Crimean-Congo haemorrhagic fever , commonly known as Congo virus, was reported on Sunday as a woman tested positive for ...",
#  'Pakistan Today',
#  '5 days ago')

# %%
Headline_element = driver.find_element_by_xpath('//*[@id="yDmH0d"]')

News = Headline_element.text.split('...\n')
import pandas as pd


News = [ ele.split('\n') for ele in News ]
print(News[0:5])
listLens = [ len(ele) for ele in News ]
print(listLens[0:5])

def mode(arr) :
    m = max([arr.count(a) for a in arr])
    return [x for x in arr if arr.count(x) == m][0] if m>1 else None
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# /usr/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# /usr/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# /usr/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# /usr/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# /usr/lib/python3.6/http/client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f9a28946780>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-116-f8347085a8d3> in <module>()
# ----> 1 Headline_element = driver.find_element_by_xpath('//*[@id="yDmH0d"]')
#       2
#       3 News = Headline_element.text.split('...\n')
#       4 import pandas as pd
#       5
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
# ---> 72                                             **urlopen_kw)
#      73
#      74     def request_encode_url(self, method, url, fields=None, headers=None,
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     321             response = conn.urlopen(method, url, **kw)
#     322         else:
# --> 323             response = conn.urlopen(method, u.request_uri, **kw)
#     324
#     325         redirect_location = redirect and response.get_redirect_location()
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     665                                 timeout=timeout, pool_timeout=pool_timeout,
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#     669         def drain_and_release_conn(response):
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     636
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#     640
#
# ~/Documents/MyProject/MyProjectVirEnv/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     396
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#     400         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=36473): Max retries exceeded with url: /session/5936fe8aaf6723bd318461049b62a22d/element (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f9a28946780>: Failed to establish a new connection: [Errno 111] Connection refused',))

# %%
def listbreak(li, breakIntoLenOf):
    liLeft = li
    brokenLi = []
    while len(liLeft) > 0:
#         print(":",liLeft[0:breakIntoLenOf])
        brokenLi.append(liLeft[0:breakIntoLenOf])
        liLeft = liLeft[breakIntoLenOf:]
    return brokenLi#( ele for ele in brokenLi )

li = ['Pakistan Today', '5 days ago', "Supreme Court rules that Karachi's JPMC will remain a federal institution", "It has rejected the Sindh govt's plea for control of the hospital.", 'Samaa Digital', '25 days ago', 'UTP who fled from JPMC may have killed traffic cop: police', 'Police believe that the under-trial prisoner (UTP) who had escaped from the Jinnah Postgraduate Medical Centre (JPMC) on January 12 may be responsible for ']
A = (ele for ele in listbreak(li,4))
type(A)
# Out:
# generator

# %%
MoreProcessedNews1, indToRemove1, MoreProcessedNews2, indToRemove2 = [], [], [], []

NewsIssue1 = [ (i,News[i]) for i in range(len(listLens)) if (listLens[i] > mode(listLens)) and (listLens[i]%mode(listLens)==0) ]
indToRemove1 = [ ele[0] for ele in NewsIssue1 ]
for ele in NewsIssue1:
    for li in listbreak(ele[1], mode(listLens)):
        MoreProcessedNews1 += tempLi

NewsIssue2 = [ (i,News[i]) for i in range(len(listLens)) if (listLens[i] > mode(listLens)) and (listLens[i]%mode(listLens)!=0) ]
indToRemove2 = [ ele[0] for ele in NewsIssue2 ]
for ele in NewsIssue2:
    for li in listbreak(ele[1], mode(listLens)):
        MoreProcessedNews2 += tempLi

# %%
pd.DataFrame(CorrectNews)
# Out:
#                              0  \
# 0                         News
# 1       The News International
# 2       The News International
# 3                     ARY NEWS
# 4          The Express Tribune
# 5                Daily Pioneer
# 6                     DAWN.com
# 7                Daily Pioneer
# 8               Pakistan Today
# 9              Hindustan Times
# 10                      openPR
# 11      The News International
# 12         The Express Tribune
# 13      The News International
# 14      The News International
# 15      The News International
# 16      The News International
# 17      The News International
# 18      The News International
# 19      The News International
# 20            Finance Magnates
# 21                    DAWN.com
# 22      The News International
# 23                Jordan Times
# 24              Pakistan Today
# 25      The News International
# 26      The News International
# 27              Pakistan Today
# 28           Pakistan Observer
# 29      Borneo Bulletin Online
# ..                         ...
# 43              Pakistan Today
# 44  Digital Signage Connection
# 45                  PYMNTS.com
# 46            The FinHeadLines
# 47              Pakistan Today
# 48      Borneo Bulletin Online
# 49            World Fertilizer
# 50      The News International
# 51         The Express Tribune
# 52                Jordan Times
# 53         SaharaReporters.com
# 54                    DAWN.com
# 55              Pakistan Today
# 56                  PYMNTS.com
# 57      The News International
# 58      The News International
# 59              Pakistan Today
# 60                Jordan Times
# 61      The News International
# 62                 PR Newswire
# 63      Borneo Bulletin Online
# 64       Technical.ly Delaware
# 65                  PYMNTS.com
# 66              Pakistan Today
# 67      The News International
# 68                    DAWN.com
# 69                     Reuters
# 70      The News International
# 71      The News International
# 72    Chicago Business Journal
#
#                                                     1  \
# 0                                             Sign in
# 1                                        one hour ago
# 2                                         17 days ago
# 3                                         25 days ago
# 4                                          4 days ago
# 5                                         11 days ago
# 6                                         21 days ago
# 7                                         23 days ago
# 8                                         25 days ago
# 9                                         24 days ago
# 10                                          yesterday
# 11                                          yesterday
# 12                                        23 days ago
# 13                                       5 months ago
# 14                                       5 months ago
# 15                                       2 months ago
# 16                                       3 months ago
# 17                                       3 months ago
# 18                                       5 months ago
# 19                                       6 months ago
# 20                                       6 months ago
# 21                                        24 days ago
# 22                                       3 months ago
# 23                                       8 months ago
# 24                                       7 months ago
# 25                                       8 months ago
# 26                                       5 months ago
# 27                                        20 days ago
# 28                                        24 days ago
# 29                                       6 months ago
# ..                                                ...
# 43                                       8 months ago
# 44                                       7 months ago
# 45  As Keycorp (KEY) Stock Value Declined, Shareho...
# 46                                          yesterday
# 47                                      10 months ago
# 48                                      11 months ago
# 49                                       8 months ago
# 50                                        10 days ago
# 51                                       4 months ago
# 52                                       9 months ago
# 53                                      10 months ago
# 54                                         last month
# 55                                       9 months ago
# 56                                      11 months ago
# 57                                      11 months ago
# 69  The time-tested friendship of Pakistan with Ch...
# 70  Doctors, paramedics and non-technical employee...
# 71                                               None
# 72                                               None
#
# [73 rows x 4 columns]

# %%
CorrectNews = [ ele for ele in News if len(ele) <= mode(listLens) ]
modeLenInColDict = {}
for i in range(mode(listLens)):
    print(i)
    colLi = [ ele[i] for ele in CorrectNews ]
    colLenLi = [ len(ele) for ele in colLi ]
    modeLenInColDict['col'+str(i)] = mode(colLi)
modeLenInColDict
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-138-bfe13d126ce7> in <module>()
#       3 for i in range(mode(listLens)):
#       4     print(i)
# ----> 5     colLi = [ ele[i] for ele in CorrectNews ]
#       6     colLenLi = [ len(ele) for ele in colLi ]
#       7     modeLenInColDict['col'+str(i)] = mode(colLi)
#
# <ipython-input-138-bfe13d126ce7> in <listcomp>(.0)
#       3 for i in range(mode(listLens)):
#       4     print(i)
# ----> 5     colLi = [ ele[i] for ele in CorrectNews ]
#       6     colLenLi = [ len(ele) for ele in colLi ]
#       7     modeLenInColDict['col'+str(i)] = mode(colLi)
#
# IndexError: list index out of range

# %%
for ele in NewsIssue2:
    print(ele[1])
    print()
# Out:
# ['Triple Pundit', 'JP Morgan Goes Big in Silicon Valley with Fintech Campus', 'Following the acquisition of WePay back in 2017, JP Morgan Chase is building upon its Fintech venture with a new Fintech campus in Silicon Valley,', 'Crowdfund Insider', '3 months ago', 'JPMC, APC to expand exports to India', 'AMMAN — Jordan Phosphate Mining Company (JPMC) and the Arab Potash Company (APC) signed a memorandum of understanding (MoUs) on Wednesday ']
#
# ['Technical.ly Delaware', 'JPMorgan tower could interfere with MTA megaproject', 'Soaring spire sits above under-construction concourse for $11 billion East Side connection to Long Island Rail Road.', "Crain's New York Business", 'last month', 'From a military career, to the business world', "Supporting veterans in their efforts after the military is important for JPMorgan Chase. Read about how they've supported Nate Fick in his CEO role after serving.", 'Chase News & Stories', '8 months ago', 'JPMorgan Chase continues hiring streak with Diversity in Tech event Sept. 28', 'With a commitment to create almost 2,000 fintech jobs in Delaware, JPMC is looking for a talented, diverse group of new hires. JPMorgan Chase continues ']
#
# ['PYMNTS.com', 'This Black Hawk Pilot Is Now Taking On Corporate America', 'Upon hearing the term Black Hawk, many Americans immediately think of pop culture. Maybe the latest Ridley Scott film or perhaps a Chicago sports team.', 'OZY', '3 months ago', 'Meet the Matchmakers Connecting Big and Small Businesses', "Seattle's Macadons is one of the few macaroon companies daring enough to experiment with flavors like durian and taro. The Seattle-based and minority-owned "]
#
# ['The News International', '10 months ago', "It's Time to Give Our Cities a Second Chance", 'Detroit is on its way to making a stunning comeback. A new initiative aims to ensure other cities get the same opportunity.', 'OZY', '5 months ago', 'Opinion', 'International transactions and sanctions compliance duties highlighted by JPMorgan lapses', "NEW YORK (Thomson Reuters Regulatory Intelligence) - The U.S. Treasury Department's $5.3 million settlement last week with JPMorgan Chase and Co. over "]

# %%
try:
    for i in range(0,1):
        driver.get("https://www.google.com/")
        driver.quit
except Exception as excpt:
    print(excpt)
    if 'about:neterror' in excpt:
        msg = 'Network Issue: Internet not available.'
        print(msg); raise Exception(msg)

# %%
# go to the google home page
driver.get("https://www.moneycontrol.com/news/commodities-news-94.html")
driver.find_element_by_id('search_str').send_keys('airtel')
driver.find_element_by_id("search_str").send_keys(Keys.ENTER)
a = driver.find_element_by_xpath("//a[contains(text(),'NEWS')]")
a.click() 
content = driver.find_elements_by_tag_name("strong")
# text = list()
# for i in range(0,40):
    
#     print content.text
#     if len(content.text) > 10:
#         text.append(content.text)
# element=driver.find_element_by_id("slider")
# dt = driver.find_element_by_tag_name("dt")
# print dt
# cl = element.find_element_by_partial_link_text("news")
# cl.click()
# time.sleep(10)
# news = driver.find_element_by_xpath("/html[1]/body[1]/div[3]/div[3]/div[1]/div[3]/div[2]/div[11]/div[1]/div[2]/div[1]/dl[1]/dt[3]/a[1]")
# href = news.get_attribute('href')
# print hreffrom selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.keys import Keys
import execjs
import time
'''
from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 800))  
display.start()
'''
options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
#binary='/usr/bin/firefox'
options.add_argument('--ignore-certificate-errors')
options.add_argument("--test-type")
# Create a new instance of the Firefox driver
#driver = webdriver.Firefox(binary)

binary = '/usr/bin/chromedriver'
driver =  webdriver.Chrome(binary,chrome_options = options)

# go to the google home page
driver.get("https://www.moneycontrol.com/news/commodities-news-94.html")
driver.find_element_by_id('search_str').send_keys('airtel')
driver.find_element_by_id("search_str").send_keys(Keys.ENTER)
a = driver.find_element_by_xpath("//a[contains(text(),'NEWS')]")
a.click() 
content = driver.find_elements_by_tag_name("strong")
# text = list()
# for i in range(0,40):
    
#     print content.text
#     if len(content.text) > 10:
#         text.append(content.text)
# element=driver.find_element_by_id("slider")
# dt = driver.find_element_by_tag_name("dt")
# print dt
# cl = element.find_element_by_partial_link_text("news")
# cl.click()
# time.sleep(10)
# news = driver.find_element_by_xpath("/html[1]/body[1]/div[3]/div[3]/div[1]/div[3]/div[2]/div[11]/div[1]/div[2]/div[1]/dl[1]/dt[3]/a[1]")
# href = news.get_attribute('href')
# print href

# %%
## Other Resource

## Selenium Other Command
# driver.back()
# driver.fullscreen_window()
# driver.minimize_window()
# driver.maximize_window()
# driver.refresh()
# driver.save_screenshot(filename='TempScreenshot.png')

## Get All Active Windows/Tabs
activeHandles = driver.window_handles

## Switch Tabs
driver.switch_to.window(activeHandles[0])
driver.switch_to.window(activeHandles[1])

## Opens another Window
# driver.execute_script("window.open('https://www.yahoo.com')")

## Open New Tab
# driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL +"t")#+Keys.TAB) #Doesn't work
homeButton = driver.find_element_by_xpath('/html/body/div/div[3]/div[1]/div/div/div/div[2]/div[2]/div[1]/a')
NewTab = Keys.CONTROL + Keys.ENTER#+ 'T'
homeButton.send_keys(NewTab)
